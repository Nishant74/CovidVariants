# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("covid-variants.csv")

# %%
df.head()
# Out:
#   location        date    variant  num_sequences  perc_sequences  \
# 0   Angola  2020-07-06      Alpha              0             0.0
# 1   Angola  2020-07-06  B.1.1.277              0             0.0
# 2   Angola  2020-07-06  B.1.1.302              0             0.0
# 3   Angola  2020-07-06  B.1.1.519              0             0.0
# 4   Angola  2020-07-06    B.1.160              0             0.0
#
#    num_sequences_total
# 0                    3
# 1                    3
# 2                    3
# 3                    3
# 4                    3

# %% [markdown]
# ### location : Country
# ### num_sequences	: Weekly number of sequences carried out.
# ### perc_sequences :100 x new_cases/number_sequenced.
# ### num_sequences_total :

# %%
df.nunique()
# Out:
# location                121
# date                     45
# variant                  24
# num_sequences          1563
# perc_sequences         3600
# num_sequences_total    1247
# dtype: int64

# %%
df["variant"].unique()
# Out:
# array(['Alpha', 'B.1.1.277', 'B.1.1.302', 'B.1.1.519', 'B.1.160',
#        'B.1.177', 'B.1.221', 'B.1.258', 'B.1.367', 'B.1.620', 'Beta',
#        'Delta', 'Epsilon', 'Eta', 'Gamma', 'Iota', 'Kappa', 'Lambda',
#        'Mu', 'Omicron', 'S:677H.Robin1', 'S:677P.Pelican', 'others',
#        'non_who'], dtype=object)

# %%
df["location"].unique()
# Out:
# array(['Angola', 'Argentina', 'Aruba', 'Australia', 'Austria', 'Bahrain',
#        'Bangladesh', 'Belgium', 'Belize', 'Benin',
#        'Bosnia and Herzegovina', 'Botswana', 'Brazil', 'Brunei',
#        'Bulgaria', 'Cambodia', 'Cameroon', 'Canada', 'Chile', 'Colombia',
#        'Costa Rica', 'Croatia', 'Curacao', 'Cyprus', 'Czechia', 'Denmark',
#        'Djibouti', 'Dominican Republic', 'Ecuador', 'Egypt', 'Estonia',
#        'Ethiopia', 'Fiji', 'Finland', 'France', 'Gambia', 'Georgia',
#        'Germany', 'Ghana', 'Greece', 'Guatemala', 'Hong Kong', 'Hungary',
#        'Iceland', 'India', 'Indonesia', 'Iran', 'Iraq', 'Ireland',
#        'Israel', 'Italy', 'Jamaica', 'Japan', 'Jordan', 'Kazakhstan',
#        'Kenya', 'Kosovo', 'Kuwait', 'Latvia', 'Lebanon', 'Liechtenstein',
#        'Lithuania', 'Luxembourg', 'Madagascar', 'Malawi', 'Malaysia',
#        'Maldives', 'Malta', 'Mauritius', 'Mexico', 'Moldova', 'Monaco',
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# location               0
# date                   0
# variant                0
# num_sequences          0
# perc_sequences         0
# num_sequences_total    0
# dtype: int64

# %%
df.describe()
# Out:
#        num_sequences  perc_sequences  num_sequences_total
# count  100416.000000   100416.000000        100416.000000
# mean       72.171676        6.154355          1509.582457
# std      1669.262169       21.898989          8445.291772
# min         0.000000       -0.010000             1.000000
# 25%         0.000000        0.000000            12.000000
# 50%         0.000000        0.000000            59.000000
# 75%         0.000000        0.000000           394.000000
# max    142280.000000      100.000000        146170.000000

# %%
df["num_sequences"].max()
# Out:
# 142280

# %%
df["num_sequences"].min()
# Out:
# 0

# %%
df.replace(0,np.nan,inplace=True)

# %%
df.dropna(inplace=True)

# %%
df=df.reset_index(drop=True, inplace=False)

# %%
df
# Out:
#        location        date  variant  num_sequences  perc_sequences  \
# 0        Angola  2020-07-06   others            3.0           100.0
# 1        Angola  2020-07-06  non_who            3.0           100.0
# 2        Angola  2020-08-31     Beta            1.0           100.0
# 3        Angola  2020-09-28     Beta            9.0            90.0
# 4        Angola  2020-09-28   others            1.0            10.0
# ...         ...         ...      ...            ...             ...
# 16102  Zimbabwe  2021-09-06    Delta           14.0           100.0
# 16103  Zimbabwe  2021-09-20    Delta            6.0           100.0
# 16104  Zimbabwe  2021-10-04    Delta            2.0           100.0
# 16105  Zimbabwe  2021-10-18    Delta            5.0           100.0
# 16106  Zimbabwe  2021-11-01    Delta            6.0           100.0
#
#        num_sequences_total
# 0                        3
# 1                        3
# 2                        1
# 3                       10
# ...

# %%
df['month'] = pd.DatetimeIndex(df['date']).month
df['month']
# Out:
# 0         7
# 1         7
# 2         8
# 3         9
# 4         9
#          ..
# 16102     9
# 16103     9
# 16104    10
# 16105    10
# 16106    11
# Name: month, Length: 16107, dtype: int64

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df
# Out:
#        location        date  variant  num_sequences  perc_sequences  \
# 0        Angola  2020-07-06   others            3.0           100.0
# 1        Angola  2020-07-06  non_who            3.0           100.0
# 2        Angola  2020-08-31     Beta            1.0           100.0
# 3        Angola  2020-09-28     Beta            9.0            90.0
# 4        Angola  2020-09-28   others            1.0            10.0
# ...         ...         ...      ...            ...             ...
# 16102  Zimbabwe  2021-09-06    Delta           14.0           100.0
# 16103  Zimbabwe  2021-09-20    Delta            6.0           100.0
# 16104  Zimbabwe  2021-10-04    Delta            2.0           100.0
# 16105  Zimbabwe  2021-10-18    Delta            5.0           100.0
# 16106  Zimbabwe  2021-11-01    Delta            6.0           100.0
#
#        num_sequences_total  month
# 0                        3      7
# 1                        3      7
# 2                        1      8
# ...

# %% [markdown]
# ## Section : 01
# ### Total Number of sequences on the basis of month

# %%
gp=df.groupby("month")["num_sequences_total"].sum()

# %%
t=gp.reset_index()

# %%
t
# Out:
#     month  num_sequences_total
# 0       1              2839950
# 1       2              3088849
# 2       3              4535821
# 3       4              5491615
# 4       5              6391788
# 5       6              2198483
# 6       7              3662993
# 7       8              5233645
# 8       9              4141427
# 9      10              3128272
# 10     11              4118224
# 11     12              3286817

# %%
t1=t.sort_values(by=["num_sequences_total"],ascending=False)

# %%
a=t.month
b=t.num_sequences_total

# %%
plt.figure(figsize=(56,24))
plt.title(" Total Weekly Number of Sequences Carried Out By Month",color="gold",fontsize=78)
plt.xlabel("Month Number",color="gold",fontsize=36)
plt.ylabel(" Number of Sequences in Million",color="gold",fontsize=36)
plt.xticks(fontsize=48,color="lightsalmon")
plt.yticks(fontsize=48,color="lightsalmon")
sns.lineplot(a,b,linewidth=20)
plt.show()
# Out:
# C:\Users\Nishant\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ## Section  Conclusion :
# ### Top 3 Month which are having highest weekly number of sequences carried out are :
# #### 1.) May : 6391788
# #### 2.) April  : 5491615
# #### 3.) August :	5233645

# %% [markdown]
# ## Section :02
# ### Total Number Of Sequences By Variants

# %%
g=df.groupby("variant")["num_sequences_total"].sum()

# %%
g=g.reset_index()

# %%
g.head()
# Out:
#      variant  num_sequences_total
# 0      Alpha              4467463
# 1  B.1.1.277               253682
# 2  B.1.1.302               186050
# 3  B.1.1.519              1345842
# 4    B.1.160              1646049

# %%
c=g.variant
d=g.num_sequences_total

# %%
plt.figure(figsize=(36,24))
plt.title(" Total Weekly Number of Sequences Carried Out By Variant",color="gold",fontsize=48)
plt.xticks(fontsize=24,color="g")
plt.yticks(fontsize=24,color="g")
sns.barplot(d,c)
plt.xlabel("Total Number of Sequences in Million",color="gold",fontsize=36)
plt.ylabel("Variant",color="gold",fontsize=36)
plt.show()
# Out:
# C:\Users\Nishant\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
g2=g.sort_values(by=["num_sequences_total"],ascending=False)

# %% [markdown]
# ## Section  Conclusion :
# ### Top Variants which are having highest weekly number of sequences carried out are :
# #### 1.) non_who : 5926742
# #### 2.) others  : 5856147
# #### 3.) Delta : 5378689
# #####  Other variants which are also significantly high are Alpha,Gamma & Beta.

# %% [markdown]
# ## Section : 03
# ### Total Number of Sequences by Location.

# %%
g2
# Out:
#            variant  num_sequences_total
# 22         non_who              5926742
# 23          others              5856147
# 11           Delta              5378689
# 0            Alpha              4467463
# 14           Gamma              3303256
# 10            Beta              2481387
# 18              Mu              2214012
# 5          B.1.177              1834775
# 13             Eta              1673001
# 4          B.1.160              1646049
# 17          Lambda              1643335
# 12         Epsilon              1603455
# 15            Iota              1544891
# 3        B.1.1.519              1345842
# 7          B.1.258              1258033
# 16           Kappa              1081239
# 6          B.1.221              1026854
# 19         Omicron               857599
# 21  S:677P.Pelican               814612
# 20   S:677H.Robin1               768409
# 9          B.1.620               738359
# 1        B.1.1.277               253682
# ...

# %%
df
# Out:
#        location        date  variant  num_sequences  perc_sequences  \
# 0        Angola  2020-07-06   others            3.0           100.0
# 1        Angola  2020-07-06  non_who            3.0           100.0
# 2        Angola  2020-08-31     Beta            1.0           100.0
# 3        Angola  2020-09-28     Beta            9.0            90.0
# 4        Angola  2020-09-28   others            1.0            10.0
# ...         ...         ...      ...            ...             ...
# 16102  Zimbabwe  2021-09-06    Delta           14.0           100.0
# 16103  Zimbabwe  2021-09-20    Delta            6.0           100.0
# 16104  Zimbabwe  2021-10-04    Delta            2.0           100.0
# 16105  Zimbabwe  2021-10-18    Delta            5.0           100.0
# 16106  Zimbabwe  2021-11-01    Delta            6.0           100.0
#
#        num_sequences_total  month
# 0                        3      7
# 1                        3      7
# 2                        1      8
# ...

# %%
h=df.groupby(["location"])["num_sequences_total"].sum()

# %%
h=h.reset_index()
h
# Out:
#           location  num_sequences_total
# 0           Angola                 5273
# 1        Argentina                53592
# 2            Aruba                13367
# 3        Australia               122673
# 4          Austria                65568
# ..             ...                  ...
# 116  United States             18883959
# 117        Uruguay                 2186
# 118        Vietnam                 1963
# 119         Zambia                 2455
# 120       Zimbabwe                 1581
#
# [121 rows x 2 columns]

# %%
h=h.sort_values(by="num_sequences_total",ascending=False)
h1=h.head(20)
h1
# Out:
#            location  num_sequences_total
# 116   United States             18883959
# 115  United Kingdom             10431486
# 37          Germany              3184866
# 25          Denmark              1810886
# 17           Canada              1720914
# 34           France              1468305
# 106          Sweden              1154063
# 52            Japan              1087374
# 107     Switzerland               775902
# 103           Spain               765296
# 50            Italy               728150
# 77      Netherlands               619699
# 7           Belgium               583706
# 44            India               563570
# 12           Brazil               500538
# 111          Turkey               385666
# 69           Mexico               322665
# 48          Ireland               238646
# 100        Slovenia               209948
# 81           Norway               207092

# %%
plt.figure(figsize=(24,16))
plt.title(" Total Weekly Number of Sequences Carried Out By Location",color="gold",fontsize=36)
plt.xticks(fontsize=24,color="g")
plt.yticks(fontsize=24,color="g")
sns.barplot(h1.num_sequences_total,h1.location)
plt.xlabel("Total Number of Sequences in Million",color="gold",fontsize=36)
plt.ylabel("Location",color="gold",fontsize=36)
plt.show()
# Out:
# C:\Users\Nishant\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ## Section  Conclusion :
# ### Top Locations which are having highest weekly number of sequences carried out are :
# #### 1.) United State  : 18883959
# #### 2.) United Kingdom : 10431486
# #### 3.) Germany : 3184866

# %% [markdown]
# 1.) non_who : 5926742
# 2.) others : 5856147
# 3.) Delta : 5378689

# %% [markdown]
# ## Section :04
# ### Top 3 Variants Analysis By Location & Month

# %%
j=df.groupby("variant")

# %%
plt.figure(figsize=(24,12))
plt.title('Top 3 Variants By Month')
plt.title(" Total Weekly Number of Sequences Carried Out By Top 3 Variants",color="gold",fontsize=36)
plt.xticks(fontsize=24,color="g")
plt.yticks(fontsize=24,color="g")
df.loc[df['variant'] == 'non_who'].groupby('month')['num_sequences_total'].agg('sum').plot(label='Non Who')
df.loc[df['variant'] == 'others'].groupby('month')['num_sequences_total'].agg('sum').plot(label='Others')
df.loc[df['variant'] == 'Delta'].groupby('month')['num_sequences_total'].agg('sum').plot(label='Delta')
plt.ylabel("Total Number of Sequences in Million",color="gold",fontsize=24)
plt.xlabel("Month",color="gold",fontsize=24)
plt.legend(fontsize=36)
plt.show()

# %%
j2=j.get_group("non_who")
j2.head(2)
# Out:
#   location        date  variant  num_sequences  perc_sequences  \
# 1   Angola  2020-07-06  non_who            3.0           100.0
# 5   Angola  2020-09-28  non_who            1.0            10.0
#
#    num_sequences_total  month
# 1                    3      7
# 5                   10      9

# %%
j3=j2.groupby(["location","month"])["num_sequences_total"].sum()
j3=j3.reset_index()
j3
# Out:
#       location  month  num_sequences_total
# 0       Angola      1                   73
# 1       Angola      2                   81
# 2       Angola      3                  234
# 3       Angola      4                  220
# 4       Angola      5                   39
# ...        ...    ...                  ...
# 1248  Zimbabwe      8                   54
# 1249  Zimbabwe      9                    8
# 1250  Zimbabwe     10                    9
# 1251  Zimbabwe     11                    1
# 1252  Zimbabwe     12                   28
#
# [1253 rows x 3 columns]

# %%
j3=j3.sort_values(by="num_sequences_total",ascending=False)
j4=j3.head(5)
j4
# Out:
#             location  month  num_sequences_total
# 1219   United States     11               348684
# 1207  United Kingdom     11               331740
# 1216   United States      8               295605
# 1217   United States      9               281316
# 1208  United Kingdom     12               237447

# %%
plt.figure(figsize=(56,24))
plt.title("non_who :Total Weekly Number of Sequences Carried Out By Month & Location ",color="gold",fontsize=78)
plt.xticks(fontsize=48,color="lightsalmon")
plt.yticks(fontsize=48,color="lightsalmon")
sns.barplot(j4.month,j4.num_sequences_total,linewidth=20,hue=j4.location)
plt.xlabel("Month Number",color="gold",fontsize=36)
plt.ylabel(" Number of Sequences in Million",color="gold",fontsize=36)
plt.legend(fontsize=48)
plt.show()
# Out:
# C:\Users\Nishant\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ### United State and United KIngdom are the  two country which are highly effected by NON_WHO variant which is vulenrable in after month August in these two country.

# %%
j6=j.get_group("others")
j6.head(2)
# Out:
#   location        date variant  num_sequences  perc_sequences  \
# 0   Angola  2020-07-06  others            3.0           100.0
# 4   Angola  2020-09-28  others            1.0            10.0
#
#    num_sequences_total  month
# 0                    3      7
# 4                   10      9

# %%
j7=j6.groupby(["location","month"])["num_sequences_total"].sum()
j7=j7.reset_index()
j7
# Out:
#       location  month  num_sequences_total
# 0       Angola      1                   73
# 1       Angola      2                   81
# 2       Angola      3                  234
# 3       Angola      4                  220
# 4       Angola      5                   39
# ...        ...    ...                  ...
# 1236  Zimbabwe      8                   54
# 1237  Zimbabwe      9                    8
# 1238  Zimbabwe     10                    9
# 1239  Zimbabwe     11                    1
# 1240  Zimbabwe     12                   28
#
# [1241 rows x 3 columns]

# %%
j7=j7.sort_values(by="num_sequences_total",ascending=False)
j8=j7.head(5)
j8
# Out:
#             location  month  num_sequences_total
# 1208   United States     11               348684
# 1196  United Kingdom     11               331740
# 1205   United States      8               295605
# 1206   United States      9               281316
# 1197  United Kingdom     12               237447

# %%
plt.figure(figsize=(56,24))
plt.title(" others :Total Weekly Number of Sequences Carried Out By Month & Location ",color="gold",fontsize=78)
plt.xticks(fontsize=48,color="lightsalmon")
plt.yticks(fontsize=48,color="lightsalmon")
sns.barplot(j4.month,j4.num_sequences_total,linewidth=20,hue=j4.location)
plt.xlabel("Month Number",color="gold",fontsize=36)
plt.ylabel(" Number of Sequences in Million",color="gold",fontsize=36)
plt.legend(fontsize=48)
plt.show()
# Out:
# C:\Users\Nishant\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ### United State and United KIngdom are the  two country which are highly effected by others variant which is vulenrable in after month August in these two country.

# %%
i6=j.get_group("Delta")
i6.head(2)
i7=i6.groupby(["location","month"])["num_sequences_total"].sum()
i7=i7.reset_index()
i7=i7.sort_values(by="num_sequences_total",ascending=False)
i8=i7.head(5)
i8
# Out:
#            location  month  num_sequences_total
# 892   United States     11               348684
# 880  United Kingdom     11               313810
# 889   United States      8               276924
# 890   United States      9               271877
# 891   United States     10               219580

# %%
plt.figure(figsize=(56,24))
plt.title(" Delta :Total Weekly Number of Sequences Carried Out By Month & Location ",color="gold",fontsize=78)
plt.xticks(fontsize=48,color="lightsalmon")
plt.yticks(fontsize=48,color="lightsalmon")
sns.barplot(j4.month,j4.num_sequences_total,linewidth=20,hue=j4.location)
plt.xlabel("Month Number",color="gold",fontsize=36)
plt.ylabel(" Number of Sequences in Million",color="gold",fontsize=36)
plt.legend(fontsize=48)
plt.show()
# Out:
# C:\Users\Nishant\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ## Section  Conclusion :
# ### 1.) United States and United Kingdom are the two country which are highly affected by the top 3 Covid Variants.
# ### 2.) From the above graphs we can see that these loactions are highly significanf from  the month of  August and there after.
# ### 3.) Most cases in the two locaton are at the month end.

# %% [markdown]
# ## Section :05
# ### Top 3 Month  Analysis By Location & Variants

# %%
plt.figure(figsize=(60,24))
plt.title('Top 3 Variants By Month')
plt.title(" Total Weekly Number of Sequences Carried Out By Top 3 Month By Variant",color="gold",fontsize=36)
plt.xticks(fontsize=24,color="g")
plt.yticks(fontsize=24,color="g")
df.loc[df['month'] == 5].groupby('variant')['num_sequences_total'].agg('sum').plot(kind="bar",label='May')
df.loc[df['month'] == 4].groupby('variant')['num_sequences_total'].agg('sum').plot(kind="bar",label='April',color="g")
df.loc[df['month'] == 8].groupby('variant')['num_sequences_total'].agg('sum').plot(kind="line",label='August',color="r")
plt.ylabel("Total Number of Sequences in Million",color="gold",fontsize=36)
plt.xlabel("Variant",color="gold",fontsize=36)
plt.legend(fontsize=24)
plt.show()

# %%
df["variant"].unique()
# Out:
# array(['others', 'non_who', 'Beta', 'Eta', 'Alpha', 'B.1.160', 'B.1.177',
#        'B.1.258', 'Kappa', 'B.1.620', 'Gamma', 'Delta', 'B.1.1.519',
#        'Lambda', 'Epsilon', 'Iota', 'Mu', 'Omicron', 'B.1.221',
#        'S:677H.Robin1', 'S:677P.Pelican', 'B.1.367', 'B.1.1.277',
#        'B.1.1.302'], dtype=object)

# %% [markdown]
# ## Section conclusion
# ### Variants Delta,Non-Who & Other are dominant in all the month.
# ### In all month of April and May other variants like S:677P.Pelican,B.1.367,Alpha are also very dominant which are leading to high case in these month.

# %% [markdown]
# ## Section : 06
# ### Indian Data Analysis

# %%
dfi=df[df["location"]=="India"]
dfi=dfi.reset_index(drop=True)
dfi
# Out:
#     location        date  variant  num_sequences  perc_sequences  \
# 0      India  2020-05-11   others          471.0          100.00
# 1      India  2020-05-11  non_who          471.0          100.00
# 2      India  2020-05-25   others          649.0          100.00
# 3      India  2020-05-25  non_who          649.0          100.00
# 4      India  2020-06-08   others          617.0          100.00
# ..       ...         ...      ...            ...             ...
# 205    India  2021-12-13  non_who           18.0            1.65
# 206    India  2021-12-27    Delta          304.0           60.92
# 207    India  2021-12-27  Omicron          174.0           34.87
# 208    India  2021-12-27   others           21.0            4.21
# 209    India  2021-12-27  non_who           21.0            4.21
#
#      num_sequences_total  month
# 0                    471      5
# 1                    471      5
# 2                    649      5
# 3                    649      5
# ...

# %%
dfi1=dfi.groupby(["variant"])["num_sequences_total"].sum()
dfi2=dfi1.reset_index()
dfi2.head()
# Out:
#    variant  num_sequences_total
# 0    Alpha                70937
# 1  B.1.160                 1293
# 2  B.1.177                 6080
# 3  B.1.258                 4160
# 4  B.1.367                 5660

# %%
dfi2=dfi2.sort_values(by="num_sequences_total",ascending=False)

# %%
dfi3=dfi2.head(10)
dfi3
# Out:
#     variant  num_sequences_total
# 16   others                91028
# 15  non_who                91028
# 7     Delta                85657
# 12    Kappa                74187
# 0     Alpha                70937
# 6      Beta                55228
# 9       Eta                39984
# 10    Gamma                21259
# 2   B.1.177                 6080
# 4   B.1.367                 5660

# %%
plt.figure(figsize=(36,24))
plt.title(" Total Weekly Number of Sequences Carried Out By Variant",color="gold",fontsize=48)
plt.xticks(fontsize=24,color="g")
plt.yticks(fontsize=24,color="g")
sns.barplot(dfi2.variant,dfi2.num_sequences_total)
plt.ylabel("Total Number of Sequences ",color="gold",fontsize=36)
plt.xlabel("Top 10 Variant",color="gold",fontsize=36)
plt.legend(fontsize=36)
plt.show()
# Out:
# C:\Users\Nishant\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# No handles with labels found to put in legend.

# %%
dfi4=dfi.groupby(["month"])["num_sequences_total"].sum()
dfi4=dfi4.reset_index()
dfi4.head()
# Out:
#    month  num_sequences_total
# 0      1                25794
# 1      2                24625
# 2      3                46151
# 3      4               102310
# 4      5               147614

# %%
plt.figure(figsize=(36,24))
plt.title(" Total Weekly Number of Sequences Carried Out By Variant",color="gold",fontsize=48)
plt.xticks(fontsize=24,color="g")
plt.yticks(fontsize=24,color="g")
sns.barplot(dfi4.month,dfi4.num_sequences_total)
plt.ylabel("Total Number of Sequences ",color="gold",fontsize=36)
plt.xlabel("Top 10 Variant",color="gold",fontsize=36)
plt.legend(fontsize=36)
plt.show()
# Out:
# C:\Users\Nishant\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# No handles with labels found to put in legend.

# %% [markdown]
# ## Section Conclusion :
# ###  I.)  As like world data India has same three dominant variants are :
# #### 1.) Others
# #### 2.) Non -Who
# #### 3.) Delta
# ####  Kappa ,Alpha And Beta are other three major variants which are highly sequenced .
#
# ### II.) The cases getting started from january but it become higher in the month of April & In the Month of May it is highese in terms of sequences and by the end of the year the overall data get reduced.

# %% [markdown]
# # Over All Conclusion :
# ## Top three dominant variant in the world is others,Non-Who & Delta,all the parts of world have similar variant as compared with India in above analysis.
# ## In case of month the cases getting higher in the month of April and getting very worse in month of May after this the cases getting decreased  for two month june and july again in month of August the cases getting higher and agains it's drops for next two month and again rises in November and then again drops down in December.

# %% [markdown]
# ## By : Nishant Sharma

# %%
df.head()
# Out:
#   location        date  variant  num_sequences  perc_sequences  \
# 0   Angola  2020-07-06   others            3.0           100.0
# 1   Angola  2020-07-06  non_who            3.0           100.0
# 2   Angola  2020-08-31     Beta            1.0           100.0
# 3   Angola  2020-09-28     Beta            9.0            90.0
# 4   Angola  2020-09-28   others            1.0            10.0
#
#    num_sequences_total  month
# 0                    3      7
# 1                    3      7
# 2                    1      8
# 3                   10      9
# 4                   10      9

# %%
df10=df.groupby("location")["num_sequences_total"].sum()

# %%
type(df10)
# Out:
# pandas.core.series.Series

# %%
df10=df.reset_index(drop=True)
df10
# Out:
#        location        date  variant  num_sequences  perc_sequences  \
# 0        Angola  2020-07-06   others            3.0           100.0
# 1        Angola  2020-07-06  non_who            3.0           100.0
# 2        Angola  2020-08-31     Beta            1.0           100.0
# 3        Angola  2020-09-28     Beta            9.0            90.0
# 4        Angola  2020-09-28   others            1.0            10.0
# ...         ...         ...      ...            ...             ...
# 16102  Zimbabwe  2021-09-06    Delta           14.0           100.0
# 16103  Zimbabwe  2021-09-20    Delta            6.0           100.0
# 16104  Zimbabwe  2021-10-04    Delta            2.0           100.0
# 16105  Zimbabwe  2021-10-18    Delta            5.0           100.0
# 16106  Zimbabwe  2021-11-01    Delta            6.0           100.0
#
#        num_sequences_total  month
# 0                        3      7
# 1                        3      7
# 2                        1      8
# ...
